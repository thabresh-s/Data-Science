# %% [markdown]
# <div style="color:orange;
#            display:fill;
#            border-radius:5px;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            background-color:black;">
#
# <p style="padding: 10px;
#               color:#0baef4;
#               text-align:center;
#               font-size:160%;">
#               📚 control flow and conditional statements 📚
#     </p>
# </div>

# %% [markdown]
# <form action="/action_page.php">
#   <fieldset>
#     <legend>Notebook Owner:</legend>
#
#    <div class="card">
#   <h5 class="card-header">Thabresh S</h5>
#   <div class="card-body">
#       <p class="card-text">thabaresh.syed@gmail.com</p>
#     <h5 class="card-title">iNeuron Assigment - 004</h5>
#     <a href="menus" class="btn btn-primary" style="color:white;" >Go somewhere</a>
#   </div>
# </div>
#
#   </fieldset>
# </form>

# %% [markdown]
# **Q1. Find the largest number from the given list, use for loop.**
#
# **numbers = [12, 75, 150, 180, 145, 525, 50]**

# %%
numbers = [12, 75, 150, 180, 145, 525, 50]

large = numbers[0]

for i in numbers:
  if i > large:
     large = i
print("Greatest number: ", large)
# Out:
# Greatest number:  525

# %% [markdown]
# **Q2. Print all the even number between (1, 12).**

# %%
start = int(input("Enter the starting range: "))
end = int(input("Enter the ending range: "))
for num in range(start,end+1):
  if num%2 == 0:
    print(num, end=" ")
# Out:
# Enter the starting range:  1
# Enter the ending range:  12
# 2 4 6 8 10 12

# %% [markdown]
# **Q3. Calculate the sum of all numbers from 1 to a given number**
#
# Expected Output:
#
# Enter number 10
#
# Sum is:  55

# %%
#define starts from 1

start = 1
end = int(input("Enter the ending number: "))
sum = 0 # initialize result
for num in range(start,end+1,1):
  sum=sum+num
print("Sum of 1 to", end, "numbers is: ", sum)
# Out:
# Enter the ending number:  10
# Sum of 1 to 10 numbers is:  55

# %% [markdown]
# **Q4. Write a program to display only those numbers from a list that satisfy the following conditions**
# - The number must be divisible by five
#
# - If the number is greater than 150, then skip it and move to the next number
#
# - If the number is greater than 500, then stop the loop

# %%
# Given:

numbers = [12, 75, 150, 180, 145, 525, 50]

# %%
a = [12, 75, 150, 180, 145, 525, 50]
b = []
for i in a: 
    #If the number is greater than 150, then skip it and move to the next number
    if i > 150:
        if i > 500: #If the number is greater than 500, then stop the loop
            break
        continue
    if i % 5 == 0: #The number must be divisible by five
        b.append(i)
        
print(b)
# Out:
# [75, 150, 145]

# %% [markdown]
# **Q5. Print the given list in reverse order.**
#
# list1 = [10, 20, 30, 40, 50]

# %%
list1 = [10, 20, 30, 40, 50]
list1.reverse()
print("Reverse order of this list is ", list1)
# Out:
# Reverse order of this list is  [50, 40, 30, 20, 10]
